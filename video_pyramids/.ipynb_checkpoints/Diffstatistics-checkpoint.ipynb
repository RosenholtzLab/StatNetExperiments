# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.utils.data as data
from torch.utils.data import DataLoader
import torch.nn as nn
import sys
import matplotlib.pyplot as plt
from tsne_torch import TorchTSNE
import numpy as np
sys.path.append('/home/gridsan/ckoevesdi/.local/lib/python3.9/site-packages/')
from pytorch_metric_learning import losses

sys.path.append('/home/gridsan/ckoevesdi/PooledStatisticsMetamers/poolstatmetamer/')
import utils.statnetencoder as sne
import importlib
import imp
import torch.nn.functional as F

#!wget https://raw.githubusercontent.com/pytorch/pytorch/master/torch/utils/collect_env.py

#sys.path.append(r'C:\Users\chris\Documents\MIT\Statistics_analysis_code\PyTorchSteerablePyramid')
sys.path.append('/home/gridsan/ckoevesdi/PyTorchSteerablePyramid/')
import steerable
import steerable.utils as utils
from steerable.SCFpyr_PyTorch import SCFpyr_PyTorch
sys.path.append('/home/gridsan/ckoevesdi/HBvsBrown/')

torch.manual_seed(16)

#use GPU 2
device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')

# %%
import utils.brucenet as bn
brucy = bn.BruceNet(pooling_region_size=1e20, pyramid_params=False, dummy_img = torch.zeros(20,
                                     1,
                                     256,
                                     256)).to(device)
# Out:
# Creating solver: pyramid=UBBBBL_6 pooling=WholeImagePooling()
# /state/partition1/llgrid/pkg/anaconda/anaconda3-2022a/lib/python3.8/site-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
ostat_labels = ['mean', 'variance', 'bandpass_variance 0', 'variance 1', 'skew 1', 'kurtosis 1', 'variance 2', 'skew 2', 'kurtosis 2', 'variance 3', 'skew 3', 'kurtosis 3', 'variance 4', 'skew 4', 'kurtosis 4', 'variance 5', 'skew 5', 'kurtosis 5', 'edge_mean 1 0', 'edge_variance 1 0', 'edge_correlation (1, 2) 0', 'edge_stop 1 0', 'edge_mean 1 1', 'edge_variance 1 1', 'edge_correlation (1, 2) 1', 'edge_stop 1 1', 'edge_mean 1 2', 'edge_variance 1 2', 'edge_correlation (1, 2) 2', 'edge_stop 1 2', 'edge_mean 1 3', 'edge_variance 1 3', 'edge_correlation (1, 2) 3', 'edge_stop 1 3', 'edge_correlation 1 (0, 1)', 'edge_correlation 1 (0, 2)', 'edge_correlation 1 (0, 3)', 'edge_correlation 1 (1, 2)', 'edge_correlation 1 (1, 3)', 'edge_correlation 1 (2, 3)', 'edge_mean 2 0', 'edge_variance 2 0', 'edge_correlation (2, 3) 0', 'edge_stop 2 0', 'edge_mean 2 1', 'edge_variance 2 1', 'edge_correlation (2, 3) 1', 'edge_stop 2 1', 'edge_mean 2 2', 'edge_variance 2 2', 'edge_correlation (2, 3) 2', 'edge_stop 2 2', 'edge_mean 2 3', 'edge_variance 2 3', 'edge_correlation (2, 3) 3', 'edge_stop 2 3', 'edge_correlation 2 (0, 1)', 'edge_correlation 2 (0, 2)', 'edge_correlation 2 (0, 3)', 'edge_correlation 2 (1, 2)', 'edge_correlation 2 (1, 3)', 'edge_correlation 2 (2, 3)', 'edge_mean 3 0', 'edge_variance 3 0', 'edge_correlation (3, 4) 0', 'edge_stop 3 0', 'edge_mean 3 1', 'edge_variance 3 1', 'edge_correlation (3, 4) 1', 'edge_stop 3 1', 'edge_mean 3 2', 'edge_variance 3 2', 'edge_correlation (3, 4) 2', 'edge_stop 3 2', 'edge_mean 3 3', 'edge_variance 3 3', 'edge_correlation (3, 4) 3', 'edge_stop 3 3', 'edge_correlation 3 (0, 1)', 'edge_correlation 3 (0, 2)', 'edge_correlation 3 (0, 3)', 'edge_correlation 3 (1, 2)', 'edge_correlation 3 (1, 3)', 'edge_correlation 3 (2, 3)', 'edge_mean 4 0', 'edge_variance 4 0', 'edge_stop 4 0', 'edge_mean 4 1', 'edge_variance 4 1', 'edge_stop 4 1', 'edge_mean 4 2', 'edge_variance 4 2', 'edge_stop 4 2', 'edge_mean 4 3', 'edge_variance 4 3', 'edge_stop 4 3', 'edge_correlation 4 (0, 1)', 'edge_correlation 4 (0, 2)', 'edge_correlation 4 (0, 3)', 'edge_correlation 4 (1, 2)', 'edge_correlation 4 (1, 3)', 'edge_correlation 4 (2, 3)', 'phase_correlation 1 er (0, 1)', 'phase_correlation 1 er (0, 2)', 'phase_correlation 1 er (0, 3)', 'phase_correlation 1 er (1, 2)', 'phase_correlation 1 er (1, 3)', 'phase_correlation 1 er (2, 3)', 'phase_correlation (1, 2) ei*di 0', 'phase_correlation (1, 2) er*di 0', 'phase_correlation (1, 2) ei*di 1', 'phase_correlation (1, 2) er*di 1', 'phase_correlation (1, 2) ei*di 2', 'phase_correlation (1, 2) er*di 2', 'phase_correlation (1, 2) ei*di 3', 'phase_correlation (1, 2) er*di 3', 'phase_correlation 2 er (0, 1)', 'phase_correlation 2 er (0, 2)', 'phase_correlation 2 er (0, 3)', 'phase_correlation 2 er (1, 2)', 'phase_correlation 2 er (1, 3)', 'phase_correlation 2 er (2, 3)', 'phase_correlation (2, 3) ei*di 0', 'phase_correlation (2, 3) er*di 0', 'phase_correlation (2, 3) ei*di 1', 'phase_correlation (2, 3) er*di 1', 'phase_correlation (2, 3) ei*di 2', 'phase_correlation (2, 3) er*di 2', 'phase_correlation (2, 3) ei*di 3', 'phase_correlation (2, 3) er*di 3', 'phase_correlation 3 er (0, 1)', 'phase_correlation 3 er (0, 2)', 'phase_correlation 3 er (0, 3)', 'phase_correlation 3 er (1, 2)', 'phase_correlation 3 er (1, 3)', 'phase_correlation 3 er (2, 3)', 'phase_correlation (3, 4) ei*di 0', 'phase_correlation (3, 4) er*di 0', 'phase_correlation (3, 4) ei*di 1', 'phase_correlation (3, 4) er*di 1', 'phase_correlation (3, 4) ei*di 2', 'phase_correlation (3, 4) er*di 2', 'phase_correlation (3, 4) ei*di 3', 'phase_correlation (3, 4) er*di 3', 'phase_correlation 4 er (0, 1)', 'phase_correlation 4 er (0, 2)', 'phase_correlation 4 er (0, 3)', 'phase_correlation 4 er (1, 2)', 'phase_correlation 4 er (1, 3)', 'phase_correlation 4 er (2, 3)']

# %%
print(ostat_labels[89])
# Out:
# edge_stop 4 1

# %%
# Path to the image
from PIL import Image

#original image is x
image_path = "/home/gridsan/ckoevesdi/HBvsBrown/pitted_0108.jpg"
x = Image.open(image_path)
x_gray = x.convert("L")
# Convert the PIL Image to a NumPy array
image_array = np.array(x_gray)
to_tensor = transforms.ToTensor()
x_tensor = to_tensor(x_gray)

## HB is y
image_path = "/home/gridsan/ckoevesdi/HBvsBrown/pitted_0108_output.jpg"
y = Image.open(image_path)
y = y.convert("L")

# Convert the PIL Image to a NumPy array
image_array = np.array(y)
to_tensor = transforms.ToTensor()
y_tensor = to_tensor(y)

## 50 from brown is z
image_path = "/home/gridsan/ckoevesdi/HBvsBrown/testing_manualstats_HeegerBergen_pitted.png"
z = Image.open(image_path)
z = z.convert("L")

# Convert the PIL Image to a NumPy array
image_array = np.array(z)
to_tensor = transforms.ToTensor()
z_tensor = to_tensor(z)


testkit = torch.stack([x_tensor, y_tensor, z_tensor]).to(device)

# %%
statistics3 = brucy(testkit)  # This should output a tensor of shape [2, 150]
print(statistics3.shape)
# Out:
# torch.Size([3, 150])

# %%
variance = [i for i, label in enumerate(ostat_labels) if 'variance' in label]
mean = [i for i, label in enumerate(ostat_labels) if 'mean' in label]
skew = [i for i, label in enumerate(ostat_labels) if 'skew' in label]
kurtosis = [i for i, label in enumerate(ostat_labels) if 'kurtosis' in label]

heegerbergen_indices = variance + mean + skew + kurtosis

# %%
print(heegerbergen_indices)
# Out:
# [1, 2, 3, 6, 9, 12, 15, 19, 23, 27, 31, 41, 45, 49, 53, 63, 67, 71, 75, 85, 88, 91, 94, 0, 18, 22, 26, 30, 40, 44, 48, 52, 62, 66, 70, 74, 84, 87, 90, 93, 4, 7, 10, 13, 16, 5, 8, 11, 14, 17]

# %%
for j in heegerbergen_indices:
    print(ostat_labels[j])
    print("-" * 20)  # Separator for clarity
    for i in range(3):
        print(statistics3[i, j])
    print("\n")
# Out:
# variance
# --------------------
# tensor(0.0772, device='cuda:0')
# tensor(0.0774, device='cuda:0')
# tensor(0.0777, device='cuda:0')
#
#
# bandpass_variance 0
# --------------------
# tensor(0.0622, device='cuda:0')
# tensor(0.0689, device='cuda:0')
# tensor(0.0623, device='cuda:0')
#
#
# variance 1
# --------------------
# tensor(0.1069, device='cuda:0')
# tensor(0.1069, device='cuda:0')
# tensor(0.1076, device='cuda:0')
#
#
# variance 2
# --------------------
# tensor(0.1437, device='cuda:0')
# tensor(0.1433, device='cuda:0')
# tensor(0.1448, device='cuda:0')
#
#
# variance 3
# --------------------
# tensor(0.1903, device='cuda:0')
# tensor(0.1895, device='cuda:0')
# tensor(0.1910, device='cuda:0')
#
#
# variance 4
# --------------------
# tensor(0.2454, device='cuda:0')
# tensor(0.2440, device='cuda:0')
# tensor(0.2447, device='cuda:0')
#
#
# variance 5
# --------------------
# tensor(0.2917, device='cuda:0')
# tensor(0.2901, device='cuda:0')
# tensor(0.2885, device='cuda:0')
#
#
# edge_variance 1 0
# --------------------
# tensor(0.2204, device='cuda:0')
# tensor(0.2308, device='cuda:0')
# tensor(0.2204, device='cuda:0')
#
#
# edge_variance 1 1
# --------------------
# tensor(0.1967, device='cuda:0')
# tensor(0.2035, device='cuda:0')
# tensor(0.1965, device='cuda:0')
#
#
# edge_variance 1 2
# --------------------
# tensor(0.1892, device='cuda:0')
# tensor(0.2002, device='cuda:0')
# tensor(0.1896, device='cuda:0')
#
#
# edge_variance 1 3
# --------------------
# tensor(0.2063, device='cuda:0')
# tensor(0.2120, device='cuda:0')
# tensor(0.2063, device='cuda:0')
#
#
# edge_variance 2 0
# --------------------
# tensor(0.3732, device='cuda:0')
# tensor(0.3833, device='cuda:0')
# tensor(0.3731, device='cuda:0')
#
#
# edge_variance 2 1
# --------------------
# tensor(0.3358, device='cuda:0')
# tensor(0.3402, device='cuda:0')
# tensor(0.3362, device='cuda:0')
#
#
# edge_variance 2 2
# --------------------
# tensor(0.3092, device='cuda:0')
# tensor(0.3268, device='cuda:0')
# tensor(0.3092, device='cuda:0')
#
#
# edge_variance 2 3
# --------------------
# tensor(0.3441, device='cuda:0')
# tensor(0.3508, device='cuda:0')
# tensor(0.3444, device='cuda:0')
#
#
# edge_variance 3 0
# --------------------
# tensor(0.5747, device='cuda:0')
# tensor(0.5812, device='cuda:0')
# tensor(0.5750, device='cuda:0')
#
#
# edge_variance 3 1
# --------------------
# tensor(0.5520, device='cuda:0')
# tensor(0.5692, device='cuda:0')
# tensor(0.5522, device='cuda:0')
#
#
# edge_variance 3 2
# --------------------
# tensor(0.6210, device='cuda:0')
# tensor(0.6601, device='cuda:0')
# tensor(0.6209, device='cuda:0')
#
#
# edge_variance 3 3
# --------------------
# tensor(0.6130, device='cuda:0')
# tensor(0.6464, device='cuda:0')
# tensor(0.6126, device='cuda:0')
#
#
# edge_variance 4 0
# --------------------
# tensor(1.2468, device='cuda:0')
# tensor(1.3273, device='cuda:0')
# tensor(1.2469, device='cuda:0')
#
#
# edge_variance 4 1
# --------------------
# tensor(1.2670, device='cuda:0')
# tensor(1.2219, device='cuda:0')
# tensor(1.2673, device='cuda:0')
#
#
# edge_variance 4 2
# --------------------
# tensor(1.4336, device='cuda:0')
# tensor(1.5490, device='cuda:0')
# tensor(1.4337, device='cuda:0')
#
#
# edge_variance 4 3
# --------------------
# tensor(1.3023, device='cuda:0')
# tensor(1.3541, device='cuda:0')
# tensor(1.3024, device='cuda:0')
#
#
# mean
# --------------------
# tensor(0.4136, device='cuda:0')
# tensor(0.4136, device='cuda:0')
# tensor(0.4160, device='cuda:0')
#
#
# edge_mean 1 0
# --------------------
# tensor(0.4104, device='cuda:0')
# tensor(0.4338, device='cuda:0')
# tensor(0.4105, device='cuda:0')
#
#
# edge_mean 1 1
# --------------------
# tensor(0.3941, device='cuda:0')
# tensor(0.4117, device='cuda:0')
# tensor(0.3947, device='cuda:0')
#
#
# edge_mean 1 2
# --------------------
# tensor(0.3836, device='cuda:0')
# tensor(0.4060, device='cuda:0')
# tensor(0.3833, device='cuda:0')
#
#
# edge_mean 1 3
# --------------------
# tensor(0.3973, device='cuda:0')
# tensor(0.4159, device='cuda:0')
# tensor(0.3977, device='cuda:0')
#
#
# edge_mean 2 0
# --------------------
# tensor(0.6741, device='cuda:0')
# tensor(0.6954, device='cuda:0')
# tensor(0.6746, device='cuda:0')
#
#
# edge_mean 2 1
# --------------------
# tensor(0.6474, device='cuda:0')
# tensor(0.6631, device='cuda:0')
# tensor(0.6474, device='cuda:0')
#
#
# edge_mean 2 2
# --------------------
# tensor(0.6323, device='cuda:0')
# tensor(0.6581, device='cuda:0')
# tensor(0.6324, device='cuda:0')
#
#
# edge_mean 2 3
# --------------------
# tensor(0.6450, device='cuda:0')
# tensor(0.6638, device='cuda:0')
# tensor(0.6450, device='cuda:0')
#
#
# edge_mean 3 0
# --------------------
# tensor(1.0904, device='cuda:0')
# tensor(1.1139, device='cuda:0')
# tensor(1.0906, device='cuda:0')
#
#
# edge_mean 3 1
# --------------------
# tensor(1.0999, device='cuda:0')
# tensor(1.1254, device='cuda:0')
# tensor(1.0999, device='cuda:0')
#
#
# edge_mean 3 2
# --------------------
# tensor(1.1543, device='cuda:0')
# tensor(1.2045, device='cuda:0')
# tensor(1.1545, device='cuda:0')
#
#
# edge_mean 3 3
# --------------------
# tensor(1.0892, device='cuda:0')
# tensor(1.1555, device='cuda:0')
# tensor(1.0892, device='cuda:0')
#
#
# edge_mean 4 0
# --------------------
# tensor(2.0085, device='cuda:0')
# tensor(2.1295, device='cuda:0')
# tensor(2.0083, device='cuda:0')
#
#
# edge_mean 4 1
# --------------------
# tensor(2.0408, device='cuda:0')
# tensor(2.0214, device='cuda:0')
# tensor(2.0409, device='cuda:0')
#
#
# edge_mean 4 2
# --------------------
# tensor(2.1991, device='cuda:0')
# tensor(2.2937, device='cuda:0')
# tensor(2.1993, device='cuda:0')
#
#
# edge_mean 4 3
# --------------------
# tensor(2.0013, device='cuda:0')
# tensor(2.1400, device='cuda:0')
# tensor(2.0013, device='cuda:0')
#
#
# skew 1
# --------------------
# tensor(0.0568, device='cuda:0')
# tensor(0.0563, device='cuda:0')
# tensor(0.0548, device='cuda:0')
#
#
# skew 2
# --------------------
# tensor(0.0716, device='cuda:0')
# tensor(0.0703, device='cuda:0')
# tensor(0.0704, device='cuda:0')
#
#
# skew 3
# --------------------
# tensor(0.0874, device='cuda:0')
# tensor(0.0849, device='cuda:0')
# tensor(0.0863, device='cuda:0')
#
#
# skew 4
# --------------------
# tensor(0.0995, device='cuda:0')
# tensor(0.0961, device='cuda:0')
# tensor(0.1002, device='cuda:0')
#
#
# skew 5
# --------------------
# tensor(0.0917, device='cuda:0')
# tensor(0.0904, device='cuda:0')
# tensor(0.0947, device='cuda:0')
#
#
# kurtosis 1
# --------------------
# tensor(0.0371, device='cuda:0')
# tensor(0.0365, device='cuda:0')
# tensor(0.0346, device='cuda:0')
#
#
# kurtosis 2
# --------------------
# tensor(0.0444, device='cuda:0')
# tensor(0.0426, device='cuda:0')
# tensor(0.0428, device='cuda:0')
#
#
# kurtosis 3
# --------------------
# tensor(0.0509, device='cuda:0')
# tensor(0.0470, device='cuda:0')
# tensor(0.0488, device='cuda:0')
#
#
# kurtosis 4
# --------------------
# tensor(0.0510, device='cuda:0')
# tensor(0.0464, device='cuda:0')
# tensor(0.0519, device='cuda:0')
#
#
# kurtosis 5
# --------------------
# tensor(0.0335, device='cuda:0')
# tensor(0.0328, device='cuda:0')
# tensor(0.0381, device='cuda:0')

# %%
all_indices = set(range(len(ostat_labels)))
remaining_indices = sorted(list(all_indices - set(heegerbergen_indices)))
for j in remaining_indices:
    print(ostat_labels[j])
    print("-" * 20)  # Separator for clarity
    for i in range(3):
        print(statistics3[i, j])
    print("\n")
# Out:
# edge_correlation (1, 2) 0
# --------------------
# tensor(0.2799, device='cuda:0')
# tensor(0.2740, device='cuda:0')
# tensor(0.2285, device='cuda:0')
#
#
# edge_stop 1 0
# --------------------
# tensor(0.0965, device='cuda:0')
# tensor(0.1198, device='cuda:0')
# tensor(0.1272, device='cuda:0')
#
#
# edge_correlation (1, 2) 1
# --------------------
# tensor(0.2514, device='cuda:0')
# tensor(0.2426, device='cuda:0')
# tensor(0.1974, device='cuda:0')
#
#
# edge_stop 1 1
# --------------------
# tensor(0.0574, device='cuda:0')
# tensor(0.0682, device='cuda:0')
# tensor(0.0736, device='cuda:0')
#
#
# edge_correlation (1, 2) 2
# --------------------
# tensor(0.2358, device='cuda:0')
# tensor(0.2345, device='cuda:0')
# tensor(0.1874, device='cuda:0')
#
#
# edge_stop 1 2
# --------------------
# tensor(0.0868, device='cuda:0')
# tensor(0.1074, device='cuda:0')
# tensor(0.1221, device='cuda:0')
#
#
# edge_correlation (1, 2) 3
# --------------------
# tensor(0.2561, device='cuda:0')
# tensor(0.2473, device='cuda:0')
# tensor(0.2046, device='cuda:0')
#
#
# edge_stop 1 3
# --------------------
# tensor(0.0570, device='cuda:0')
# tensor(0.0730, device='cuda:0')
# tensor(0.0758, device='cuda:0')
#
#
# edge_correlation 1 (0, 1)
# --------------------
# tensor(0.1730, device='cuda:0')
# tensor(0.1810, device='cuda:0')
# tensor(0.1690, device='cuda:0')
#
#
# edge_correlation 1 (0, 2)
# --------------------
# tensor(0.1467, device='cuda:0')
# tensor(0.1547, device='cuda:0')
# tensor(0.1313, device='cuda:0')
#
#
# edge_correlation 1 (0, 3)
# --------------------
# tensor(0.1769, device='cuda:0')
# tensor(0.1851, device='cuda:0')
# tensor(0.1707, device='cuda:0')
#
#
# edge_correlation 1 (1, 2)
# --------------------
# tensor(0.1599, device='cuda:0')
# tensor(0.1676, device='cuda:0')
# tensor(0.1523, device='cuda:0')
#
#
# edge_correlation 1 (1, 3)
# --------------------
# tensor(0.1487, device='cuda:0')
# tensor(0.1515, device='cuda:0')
# tensor(0.1374, device='cuda:0')
#
#
# edge_correlation 1 (2, 3)
# --------------------
# tensor(0.1627, device='cuda:0')
# tensor(0.1715, device='cuda:0')
# tensor(0.1598, device='cuda:0')
#
#
# edge_correlation (2, 3) 0
# --------------------
# tensor(0.4394, device='cuda:0')
# tensor(0.4301, device='cuda:0')
# tensor(0.4240, device='cuda:0')
#
#
# edge_stop 2 0
# --------------------
# tensor(0.2874, device='cuda:0')
# tensor(0.3724, device='cuda:0')
# tensor(0.2786, device='cuda:0')
#
#
# edge_correlation (2, 3) 1
# --------------------
# tensor(0.4136, device='cuda:0')
# tensor(0.3975, device='cuda:0')
# tensor(0.3585, device='cuda:0')
#
#
# edge_stop 2 1
# --------------------
# tensor(0.2913, device='cuda:0')
# tensor(0.3314, device='cuda:0')
# tensor(0.3122, device='cuda:0')
#
#
# edge_correlation (2, 3) 2
# --------------------
# tensor(0.4232, device='cuda:0')
# tensor(0.4263, device='cuda:0')
# tensor(0.3949, device='cuda:0')
#
#
# edge_stop 2 2
# --------------------
# tensor(0.2273, device='cuda:0')
# tensor(0.2877, device='cuda:0')
# tensor(0.2393, device='cuda:0')
#
#
# edge_correlation (2, 3) 3
# --------------------
# tensor(0.4305, device='cuda:0')
# tensor(0.4355, device='cuda:0')
# tensor(0.3932, device='cuda:0')
#
#
# edge_stop 2 3
# --------------------
# tensor(0.2772, device='cuda:0')
# tensor(0.3356, device='cuda:0')
# tensor(0.3177, device='cuda:0')
#
#
# edge_correlation 2 (0, 1)
# --------------------
# tensor(0.2915, device='cuda:0')
# tensor(0.3036, device='cuda:0')
# tensor(0.2927, device='cuda:0')
#
#
# edge_correlation 2 (0, 2)
# --------------------
# tensor(0.2415, device='cuda:0')
# tensor(0.2571, device='cuda:0')
# tensor(0.2429, device='cuda:0')
#
#
# edge_correlation 2 (0, 3)
# --------------------
# tensor(0.2981, device='cuda:0')
# tensor(0.3080, device='cuda:0')
# tensor(0.2876, device='cuda:0')
#
#
# edge_correlation 2 (1, 2)
# --------------------
# tensor(0.2659, device='cuda:0')
# tensor(0.2767, device='cuda:0')
# tensor(0.2581, device='cuda:0')
#
#
# edge_correlation 2 (1, 3)
# --------------------
# tensor(0.2405, device='cuda:0')
# tensor(0.2522, device='cuda:0')
# tensor(0.2260, device='cuda:0')
#
#
# edge_correlation 2 (2, 3)
# --------------------
# tensor(0.2630, device='cuda:0')
# tensor(0.2807, device='cuda:0')
# tensor(0.2712, device='cuda:0')
#
#
# edge_correlation (3, 4) 0
# --------------------
# tensor(0.8344, device='cuda:0')
# tensor(0.8383, device='cuda:0')
# tensor(0.8180, device='cuda:0')
#
#
# edge_stop 3 0
# --------------------
# tensor(0.5529, device='cuda:0')
# tensor(0.5168, device='cuda:0')
# tensor(0.3380, device='cuda:0')
#
#
# edge_correlation (3, 4) 1
# --------------------
# tensor(0.7883, device='cuda:0')
# tensor(0.8290, device='cuda:0')
# tensor(0.7301, device='cuda:0')
#
#
# edge_stop 3 1
# --------------------
# tensor(0.4456, device='cuda:0')
# tensor(0.4272, device='cuda:0')
# tensor(0.4834, device='cuda:0')
#
#
# edge_correlation (3, 4) 2
# --------------------
# tensor(0.9213, device='cuda:0')
# tensor(0.9488, device='cuda:0')
# tensor(0.8329, device='cuda:0')
#
#
# edge_stop 3 2
# --------------------
# tensor(0.5112, device='cuda:0')
# tensor(0.5809, device='cuda:0')
# tensor(0.4497, device='cuda:0')
#
#
# edge_correlation (3, 4) 3
# --------------------
# tensor(0.8710, device='cuda:0')
# tensor(0.8844, device='cuda:0')
# tensor(0.7606, device='cuda:0')
#
#
# edge_stop 3 3
# --------------------
# tensor(0.5745, device='cuda:0')
# tensor(0.5731, device='cuda:0')
# tensor(0.4720, device='cuda:0')
#
#
# edge_correlation 3 (0, 1)
# --------------------
# tensor(0.4668, device='cuda:0')
# tensor(0.4657, device='cuda:0')
# tensor(0.4606, device='cuda:0')
#
#
# edge_correlation 3 (0, 2)
# --------------------
# tensor(0.4372, device='cuda:0')
# tensor(0.4582, device='cuda:0')
# tensor(0.4545, device='cuda:0')
#
#
# edge_correlation 3 (0, 3)
# --------------------
# tensor(0.5020, device='cuda:0')
# tensor(0.5245, device='cuda:0')
# tensor(0.4921, device='cuda:0')
#
#
# edge_correlation 3 (1, 2)
# --------------------
# tensor(0.4875, device='cuda:0')
# tensor(0.5210, device='cuda:0')
# tensor(0.4762, device='cuda:0')
#
#
# edge_correlation 3 (1, 3)
# --------------------
# tensor(0.4182, device='cuda:0')
# tensor(0.4476, device='cuda:0')
# tensor(0.4091, device='cuda:0')
#
#
# edge_correlation 3 (2, 3)
# --------------------
# tensor(0.5107, device='cuda:0')
# tensor(0.5358, device='cuda:0')
# tensor(0.5262, device='cuda:0')
#
#
# edge_stop 4 0
# --------------------
# tensor(0.5877, device='cuda:0')
# tensor(0.4720, device='cuda:0')
# tensor(0.3440, device='cuda:0')
#
#
# edge_stop 4 1
# --------------------
# tensor(0.4963, device='cuda:0')
# tensor(0.4259, device='cuda:0')
# tensor(0.5671, device='cuda:0')
#
#
# edge_stop 4 2
# --------------------
# tensor(0.5279, device='cuda:0')
# tensor(0.6792, device='cuda:0')
# tensor(0.6296, device='cuda:0')
#
#
# edge_stop 4 3
# --------------------
# tensor(0.4618, device='cuda:0')
# tensor(0.4124, device='cuda:0')
# tensor(0.7720, device='cuda:0')
#
#
# edge_correlation 4 (0, 1)
# --------------------
# tensor(1.0555, device='cuda:0')
# tensor(1.0532, device='cuda:0')
# tensor(0.9689, device='cuda:0')
#
#
# edge_correlation 4 (0, 2)
# --------------------
# tensor(1.0572, device='cuda:0')
# tensor(1.0198, device='cuda:0')
# tensor(0.8832, device='cuda:0')
#
#
# edge_correlation 4 (0, 3)
# --------------------
# tensor(1.0969, device='cuda:0')
# tensor(1.1241, device='cuda:0')
# tensor(0.9889, device='cuda:0')
#
#
# edge_correlation 4 (1, 2)
# --------------------
# tensor(1.1366, device='cuda:0')
# tensor(1.1909, device='cuda:0')
# tensor(1.1057, device='cuda:0')
#
#
# edge_correlation 4 (1, 3)
# --------------------
# tensor(0.9197, device='cuda:0')
# tensor(0.9755, device='cuda:0')
# tensor(0.8860, device='cuda:0')
#
#
# edge_correlation 4 (2, 3)
# --------------------
# tensor(1.1568, device='cuda:0')
# tensor(1.1998, device='cuda:0')
# tensor(1.1424, device='cuda:0')
#
#
# phase_correlation 1 er (0, 1)
# --------------------
# tensor(0.3013, device='cuda:0')
# tensor(0.3116, device='cuda:0')
# tensor(0.3032, device='cuda:0')
#
#
# phase_correlation 1 er (0, 2)
# --------------------
# tensor(-0.0031, device='cuda:0')
# tensor(-0.0022, device='cuda:0')
# tensor(-0.0028, device='cuda:0')
#
#
# phase_correlation 1 er (0, 3)
# --------------------
# tensor(-0.3074, device='cuda:0')
# tensor(-0.3183, device='cuda:0')
# tensor(-0.3041, device='cuda:0')
#
#
# phase_correlation 1 er (1, 2)
# --------------------
# tensor(0.2658, device='cuda:0')
# tensor(0.2788, device='cuda:0')
# tensor(0.2635, device='cuda:0')
#
#
# phase_correlation 1 er (1, 3)
# --------------------
# tensor(-0.0089, device='cuda:0')
# tensor(-0.0087, device='cuda:0')
# tensor(-0.0087, device='cuda:0')
#
#
# phase_correlation 1 er (2, 3)
# --------------------
# tensor(0.2761, device='cuda:0')
# tensor(0.2896, device='cuda:0')
# tensor(0.2812, device='cuda:0')
#
#
# phase_correlation (1, 2) ei*di 0
# --------------------
# tensor(-0.0110, device='cuda:0')
# tensor(-0.0174, device='cuda:0')
# tensor(0.0051, device='cuda:0')
#
#
# phase_correlation (1, 2) er*di 0
# --------------------
# tensor(0.1732, device='cuda:0')
# tensor(0.2120, device='cuda:0')
# tensor(0.1303, device='cuda:0')
#
#
# phase_correlation (1, 2) ei*di 1
# --------------------
# tensor(-0.0088, device='cuda:0')
# tensor(0.0095, device='cuda:0')
# tensor(0.0220, device='cuda:0')
#
#
# phase_correlation (1, 2) er*di 1
# --------------------
# tensor(0.1473, device='cuda:0')
# tensor(0.1978, device='cuda:0')
# tensor(0.1223, device='cuda:0')
#
#
# phase_correlation (1, 2) ei*di 2
# --------------------
# tensor(0.0014, device='cuda:0')
# tensor(0.0179, device='cuda:0')
# tensor(0.0050, device='cuda:0')
#
#
# phase_correlation (1, 2) er*di 2
# --------------------
# tensor(0.1573, device='cuda:0')
# tensor(0.2055, device='cuda:0')
# tensor(0.1395, device='cuda:0')
#
#
# phase_correlation (1, 2) ei*di 3
# --------------------
# tensor(0.0228, device='cuda:0')
# tensor(-0.0026, device='cuda:0')
# tensor(0.0153, device='cuda:0')
#
#
# phase_correlation (1, 2) er*di 3
# --------------------
# tensor(0.1651, device='cuda:0')
# tensor(0.1923, device='cuda:0')
# tensor(0.1260, device='cuda:0')
#
#
# phase_correlation 2 er (0, 1)
# --------------------
# tensor(0.5068, device='cuda:0')
# tensor(0.5239, device='cuda:0')
# tensor(0.5323, device='cuda:0')
#
#
# phase_correlation 2 er (0, 2)
# --------------------
# tensor(-0.0045, device='cuda:0')
# tensor(-0.0031, device='cuda:0')
# tensor(-0.0024, device='cuda:0')
#
#
# phase_correlation 2 er (0, 3)
# --------------------
# tensor(-0.5234, device='cuda:0')
# tensor(-0.5298, device='cuda:0')
# tensor(-0.5139, device='cuda:0')
#
#
# phase_correlation 2 er (1, 2)
# --------------------
# tensor(0.4568, device='cuda:0')
# tensor(0.4591, device='cuda:0')
# tensor(0.4384, device='cuda:0')
#
#
# phase_correlation 2 er (1, 3)
# --------------------
# tensor(-0.0167, device='cuda:0')
# tensor(-0.0143, device='cuda:0')
# tensor(-0.0173, device='cuda:0')
#
#
# phase_correlation 2 er (2, 3)
# --------------------
# tensor(0.4469, device='cuda:0')
# tensor(0.4739, device='cuda:0')
# tensor(0.4784, device='cuda:0')
#
#
# phase_correlation (2, 3) ei*di 0
# --------------------
# tensor(-0.0503, device='cuda:0')
# tensor(0.0347, device='cuda:0')
# tensor(-0.1208, device='cuda:0')
#
#
# phase_correlation (2, 3) er*di 0
# --------------------
# tensor(0.2711, device='cuda:0')
# tensor(0.3244, device='cuda:0')
# tensor(0.3860, device='cuda:0')
#
#
# phase_correlation (2, 3) ei*di 1
# --------------------
# tensor(0.0466, device='cuda:0')
# tensor(0.1087, device='cuda:0')
# tensor(-0.0069, device='cuda:0')
#
#
# phase_correlation (2, 3) er*di 1
# --------------------
# tensor(0.1950, device='cuda:0')
# tensor(0.2425, device='cuda:0')
# tensor(0.3080, device='cuda:0')
#
#
# phase_correlation (2, 3) ei*di 2
# --------------------
# tensor(0.0880, device='cuda:0')
# tensor(0.0593, device='cuda:0')
# tensor(0.0714, device='cuda:0')
#
#
# phase_correlation (2, 3) er*di 2
# --------------------
# tensor(0.1999, device='cuda:0')
# tensor(0.2704, device='cuda:0')
# tensor(0.3544, device='cuda:0')
#
#
# phase_correlation (2, 3) ei*di 3
# --------------------
# tensor(0.0058, device='cuda:0')
# tensor(-0.0396, device='cuda:0')
# tensor(-0.0559, device='cuda:0')
#
#
# phase_correlation (2, 3) er*di 3
# --------------------
# tensor(0.1284, device='cuda:0')
# tensor(0.3043, device='cuda:0')
# tensor(0.3168, device='cuda:0')
#
#
# phase_correlation 3 er (0, 1)
# --------------------
# tensor(0.7564, device='cuda:0')
# tensor(0.7668, device='cuda:0')
# tensor(0.8025, device='cuda:0')
#
#
# phase_correlation 3 er (0, 2)
# --------------------
# tensor(-0.0186, device='cuda:0')
# tensor(-0.0119, device='cuda:0')
# tensor(-0.0120, device='cuda:0')
#
#
# phase_correlation 3 er (0, 3)
# --------------------
# tensor(-0.8884, device='cuda:0')
# tensor(-0.9119, device='cuda:0')
# tensor(-0.8534, device='cuda:0')
#
#
# phase_correlation 3 er (1, 2)
# --------------------
# tensor(0.8654, device='cuda:0')
# tensor(0.8869, device='cuda:0')
# tensor(0.8322, device='cuda:0')
#
#
# phase_correlation 3 er (1, 3)
# --------------------
# tensor(0.0299, device='cuda:0')
# tensor(0.0161, device='cuda:0')
# tensor(0.0039, device='cuda:0')
#
#
# phase_correlation 3 er (2, 3)
# --------------------
# tensor(0.8735, device='cuda:0')
# tensor(0.9416, device='cuda:0')
# tensor(0.9339, device='cuda:0')
#
#
# phase_correlation (3, 4) ei*di 0
# --------------------
# tensor(0.0191, device='cuda:0')
# tensor(0.2511, device='cuda:0')
# tensor(-0.2647, device='cuda:0')
#
#
# phase_correlation (3, 4) er*di 0
# --------------------
# tensor(0.5463, device='cuda:0')
# tensor(0.5860, device='cuda:0')
# tensor(0.7268, device='cuda:0')
#
#
# phase_correlation (3, 4) ei*di 1
# --------------------
# tensor(0.0352, device='cuda:0')
# tensor(0.3914, device='cuda:0')
# tensor(-0.2013, device='cuda:0')
#
#
# phase_correlation (3, 4) er*di 1
# --------------------
# tensor(0.3493, device='cuda:0')
# tensor(0.6096, device='cuda:0')
# tensor(0.5889, device='cuda:0')
#
#
# phase_correlation (3, 4) ei*di 2
# --------------------
# tensor(0.1700, device='cuda:0')
# tensor(0.1466, device='cuda:0')
# tensor(0.0501, device='cuda:0')
#
#
# phase_correlation (3, 4) er*di 2
# --------------------
# tensor(0.5146, device='cuda:0')
# tensor(0.7765, device='cuda:0')
# tensor(0.5964, device='cuda:0')
#
#
# phase_correlation (3, 4) ei*di 3
# --------------------
# tensor(0.0258, device='cuda:0')
# tensor(0.0043, device='cuda:0')
# tensor(-0.0878, device='cuda:0')
#
#
# phase_correlation (3, 4) er*di 3
# --------------------
# tensor(0.8034, device='cuda:0')
# tensor(0.7684, device='cuda:0')
# tensor(0.4894, device='cuda:0')
#
#
# phase_correlation 4 er (0, 1)
# --------------------
# tensor(1.7239, device='cuda:0')
# tensor(1.7064, device='cuda:0')
# tensor(1.7457, device='cuda:0')
#
#
# phase_correlation 4 er (0, 2)
# --------------------
# tensor(-0.0164, device='cuda:0')
# tensor(-0.0112, device='cuda:0')
# tensor(-0.0140, device='cuda:0')
#
#
# phase_correlation 4 er (0, 3)
# --------------------
# tensor(-1.7927, device='cuda:0')
# tensor(-1.9572, device='cuda:0')
# tensor(-1.7592, device='cuda:0')
#
#
# phase_correlation 4 er (1, 2)
# --------------------
# tensor(1.9510, device='cuda:0')
# tensor(2.0554, device='cuda:0')
# tensor(2.0067, device='cuda:0')
#
#
# phase_correlation 4 er (1, 3)
# --------------------
# tensor(0.1014, device='cuda:0')
# tensor(0.0523, device='cuda:0')
# tensor(-0.0162, device='cuda:0')
#
#
# phase_correlation 4 er (2, 3)
# --------------------
# tensor(2.0342, device='cuda:0')
# tensor(2.1169, device='cuda:0')
# tensor(2.0542, device='cuda:0')

# %%
# Path to the image
from PIL import Image
image_path = "/home/gridsan/ckoevesdi/Testobreal/43.jpg"

# Read the image
y = Image.open(image_path)
y = y.convert("L")

# Convert the PIL Image to a NumPy array
image_array = np.array(y)
to_tensor = transforms.ToTensor()
y_tensor = to_tensor(y)
yy = torch.stack([y_tensor, y_tensor]).to(device)
print(yy.shape)
# Out:
# torch.Size([2, 1, 630, 840])

# %%
# Path to the image
from PIL import Image
image_path = "/home/gridsan/ckoevesdi/Testobreal/orig.jpg"

# Read the image
y = Image.open(image_path)
y = y.convert("L")

# Convert the PIL Image to a NumPy array
image_array = np.array(y)
to_tensor = transforms.ToTensor()
y_tensor = to_tensor(y)
zz = torch.stack([y_tensor, y_tensor]).to(device)
print(zz.shape)
# Out:
# torch.Size([2, 1, 630, 840])

# %%
statistics3 = brucy(zz)  # This should output a tensor of shape [2, 150]
statistics3 = statistics3[0,:]
print(statistics3)
# Out:
# tensor([ 1.7058e+00,  8.0517e-01,  8.1627e-02,  1.1353e+00,  1.1008e+00,
#          1.0808e+00,  1.5949e+00,  1.5414e+00,  1.5111e+00,  2.2290e+00,
#          2.1419e+00,  2.0943e+00,  3.1081e+00,  2.9692e+00,  2.8972e+00,
#          4.3199e+00,  4.1002e+00,  3.9893e+00,  3.6685e-01,  3.4274e-01,
#          5.1597e-01,  9.8224e-02,  2.3651e-01,  1.3014e-01,  1.4534e-01,
#          3.8183e-02,  2.3796e-01,  1.7185e-01,  2.7811e-01,  5.3021e-02,
#          3.9533e-01,  3.4713e-01,  5.9272e-01,  3.9181e-02,  1.6927e-01,
#          1.1434e-01,  2.8802e-01,  1.1193e-01,  1.7591e-01,  1.7174e-01,
#          7.1330e-01,  7.7737e-01,  9.3105e-01,  3.1284e-01,  3.5216e-01,
#          1.8018e-01,  2.2466e-01,  1.2615e-01,  4.9931e-01,  4.3140e-01,
#          5.7732e-01,  1.6890e-01,  8.7638e-01,  1.1124e+00,  1.1984e+00,
#          4.5787e-01,  2.8173e-01,  2.8274e-01,  7.8357e-01,  2.0124e-01,
#          3.0736e-01,  5.0111e-01,  1.1278e+00,  1.1807e+00,  1.3282e+00,
#          4.5527e-01,  6.0029e-01,  2.8542e-01,  3.6236e-01,  1.9767e-01,
#          8.7463e-01,  7.6084e-01,  1.0949e+00,  2.4200e-01,  1.2690e+00,
#          1.4324e+00,  1.2187e+00,  6.4265e-01,  4.3272e-01,  4.2498e-01,
#          1.0840e+00,  3.5022e-01,  4.5469e-01,  7.2193e-01,  1.6922e+00,
#          1.5785e+00,  4.6642e-01,  1.0618e+00,  4.7893e-01,  3.3479e-01,
#          1.5823e+00,  1.4868e+00,  2.4220e-01,  1.5867e+00,  1.1342e+00,
#          6.0427e-01,  6.4184e-01,  4.8868e-01,  1.0447e+00,  6.5116e-01,
#          5.8421e-01,  8.7134e-01,  2.8328e-01, -5.3700e-02, -6.2290e-01,
#          1.8640e-01, -3.4401e-02,  3.1021e-01, -7.6188e-02,  1.0663e-01,
#          1.8795e-03,  9.5083e-03,  9.7161e-03,  5.2266e-02,  1.2957e-01,
#          6.6860e-02,  4.4609e-01, -2.2977e-01, -1.7568e+00,  3.2473e-01,
#         -6.2792e-02,  1.0103e+00,  1.1342e-01,  2.6058e-01,  3.6228e-02,
#          7.0138e-02, -4.3322e-02,  3.0100e-01, -2.0209e-02,  3.0357e-01,
#          7.4224e-01, -2.8124e-01, -2.3838e+00,  6.1535e-01, -7.2583e-02,
#          1.4383e+00,  1.5142e-01,  3.7243e-01, -1.8816e-05,  5.1491e-02,
#          2.7511e-02,  4.4354e-01, -4.5494e-03,  1.2686e-01,  1.2646e+00,
#         -1.5050e-01, -2.2645e+00,  1.3398e+00,  1.2217e-02,  1.8057e+00],
#        device='cuda:0')

# %%
statistics = brucy(yy)  # This should output a tensor of shape [2, 150]
statistics = statistics[0,:]

# %%
statistics2 = brucy(xx)  # This should output a tensor of shape [2, 150]
statistics2 = statistics2[0,:]

# %%
print(statistics2)

# %%
print(statistics)

# %%
import torch
import torch.nn.functional as F


# Slice the vectors to get the first 50 and last 50 elements
yy_first50 = statistics[20:50]
zz_first50 = statistics3[20:50]
yy_last50 = statistics[100:130]
zz_last50 = statistics3[100:130]

# Compute the MSE between the first 50 elements of each vector
mse_first50 = F.mse_loss(yy_first50, zz_first50)

# Compute the MSE between the last 50 elements of each vector
mse_last50 = F.mse_loss(yy_last50, zz_last50)

# Print the results
print(f"MSE for first 50 elements: {mse_first50.item()}")
print(f"MSE for last 50 elements: {mse_last50.item()}")
# Out:
# MSE for first 50 elements: 0.0008842774550430477
# MSE for last 50 elements: 0.006435114424675703

# %%
import torch
import torch.nn.functional as F


# Slice the vectors to get the first 50 and last 50 elements
yy_first50 = statistics[:50]
zz_first50 = statistics3[:50]
yy_last50 = statistics[50:100]
zz_last50 = statistics3[50:100]

# Compute the MSE between the first 50 elements of each vector
mse_first50 = F.mse_loss(statistics, statistics3)

# Compute the MSE between the last 50 elements of each vector
mse_last50 = F.mse_loss(statistics2, statistics3)

# Print the results
print(f"MSE for first 50 elements: {mse_first50.item()}")
print(f"MSE for last 50 elements: {mse_last50.item()}")
# Out:
# MSE for first 50 elements: 0.0041005113162100315
# MSE for last 50 elements: 0.0033451493363827467

# %%
print(yy)
